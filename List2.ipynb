# %% [markdown]
# <a href="https://colab.research.google.com/github/Umargambo/Simple-C-Calculator/blob/master/List2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_drones = ["Zaki 1", "Zaki 2"]
my_drones.append("Zaki 3") # Adding a new drone
print(my_drones)
print(len(my_drones)) # This will show 3
# Out:
# ['Zaki 1', 'Zaki 2', 'Zaki 3']
# 3
