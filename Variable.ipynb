# %% [markdown]
# <a href="https://colab.research.google.com/github/Umargambo/Simple-C-Calculator/blob/master/Variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Storing drone data
name = "Elite Zaki"
battery = 85
is_flying = False

print(type(name))
print(type(battery))
print(type(is_flying))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
