# %% [markdown]
# <a href="https://colab.research.google.com/github/Umargambo/Simple-C-Calculator/blob/master/Loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# List din ka
intruder_ids = [101, 102, 103]

# Canza 102 zuwa 999
intruder_ids[1] = 999

print(intruder_ids)
# Sakamakon zai zama: [101, 999, 103]
# Out:
# [101, 999, 103]
