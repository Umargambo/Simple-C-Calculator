# %% [markdown]
# <a href="https://colab.research.google.com/github/Umargambo/Simple-C-Calculator/blob/master/Elite%20zaki%202028.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Wannan shine sharhi na farko (This is my first comment)
# Ina koyon Python don aikin 'Elite Zaki'

print("Sannu da zuwa duniyar Python!") # Printing in Hausa
print("My name is Umar Gambo.")       # Printing in English

# Let's do some math for industrial pipe inspection
print(50 + 25) # If I have 50 pipes and add 25 more
# Out:
# Sannu da zuwa duniyar Python!
# My name is Umar Gambo.
# 75
