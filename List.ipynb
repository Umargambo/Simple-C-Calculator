# %% [markdown]
# <a href="https://colab.research.google.com/github/Umargambo/Simple-C-Calculator/blob/master/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# List of drone parts
drone_parts = ["Motor", "Battery", "Propeller", "Camera"]

# List of sensor readings (Numbers)
sensor_readings = [25.4, 30.2, 12.5, 45.0]
